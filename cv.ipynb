# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/shreyas/anaconda3/envs/llm/lib/python3.11/site-packages (from opencv-python) (1.23.5)
# Downloading opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 169.3 kB/s eta 0:00:0000:0100:03
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Canny Edge

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image = cv2.imread('./GOODGRAPE/IR_00002.JPG', cv2.IMREAD_GRAYSCALE)

# Apply Canny Edge Detector
edges = cv2.Canny(image, threshold1=100, threshold2=200)

# Display the result
plt.figure(figsize=(8, 6))
plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Harris Corner

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('./GOODGRAPE/IR_00002.JPG')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)

dst = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

dst = cv2.dilate(dst, None)

image[dst > 0.01 * dst.max()] = [0, 0, 255]

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Corner Image')
plt.xticks([]), plt.yticks([])
plt.show()
